# %%
# !git clone https://github.com/AdityaSinghDevs/nanolens
# %cd nanolens
# Out:
# Cloning into 'nanolens'...
# remote: Enumerating objects: 143, done.
# remote: Counting objects: 100% (143/143), done.
# remote: Compressing objects: 100% (88/88), done.
# remote: Total 143 (delta 67), reused 118 (delta 45), pack-reused 0 (from 0)
# Receiving objects: 100% (143/143), 40.06 MiB | 22.59 MiB/s, done.
# Resolving deltas: 100% (67/67), done.
# /content/nanolens

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.makedirs('/content/drive/MyDrive/nanolens/checkpoints', exist_ok=True)
print("Drive checkpoint folder ready")
# Out:
# Drive checkpoint folder ready

# %%
# !pip install torch pyaml

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# Tesla T4

# %%
import sys
sys.path.insert(0, '.')

# %%
# !python cli.py --checkpoint /content/drive/MyDrive/nanolens/checkpoints/gpt_L8_H8_E512_3000.pt --resume 3000
# Out:
# Resumec from /content/drive/MyDrive/nanolens/checkpoints/gpt_L8_H8_E512_3000.pt
# Everything sticked together well, Training Started..
# step 3000: train loss 1.1146, val loss 1.1511, lr 0.000127
# Saved locally -> checkpoints/gpt_L8_H8_E512_3000.pt
# Saved to Drive → /content/drive/MyDrive/nanolens/checkpoints/gpt_L8_H8_E512_3000.pt
# step 3300: train loss 1.0995, val loss 1.1405, lr 0.000103
# Saved locally -> checkpoints/gpt_L8_H8_E512_3500.pt
# Saved to Drive → /content/drive/MyDrive/nanolens/checkpoints/gpt_L8_H8_E512_3500.pt
# step 3600: train loss 1.0885, val loss 1.1311, lr 0.000081
# step 3900: train loss 1.0770, val loss 1.1259, lr 0.000062
# Saved locally -> checkpoints/gpt_L8_H8_E512_4000.pt
# Saved to Drive → /content/drive/MyDrive/nanolens/checkpoints/gpt_L8_H8_E512_4000.pt
# step 4200: train loss 1.0713, val loss 1.1203, lr 0.000047
# step 4500: train loss 1.0629, val loss 1.1172, lr 0.000037
# Saved locally -> checkpoints/gpt_L8_H8_E512_4500.pt
# ...
